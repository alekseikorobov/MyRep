# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in [1,2]:
    print(i)
# Out:
# 1
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(1+1)
# Out:
# 2

# %%
a = input()
print(int(a) + 1)
# Out:
# r
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5912/536225124.py in <module>
#       1 a = input()
# ----> 2 print(int(a) + 1)
#
# ValueError: invalid literal for int() with base 10: 'r'
